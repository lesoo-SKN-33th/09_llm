# %% [markdown]
# # Tool 호출 루프가 있는 LangGraph Chatbot
#
# 일반 Chat Model은 질문을 읽고 답변을 한 번 생성한다. Tool이 연결된 Chat Model은 답변에 외부 정보가 필요하면 검색이나 계산 같은 기능의 **실행 요청**을 만들 수 있다.
#
# 모델이 Tool을 직접 실행하는 것은 아니다. <br>
# 모델은 `AIMessage.tool_calls`를 만들고, LangGraph의 Tool Node가 요청을 실행해 `ToolMessage`로 돌려준다. <br>
# 모델은 그 결과를 다시 읽고 최종 답변을 만들거나 다른 Tool을 요청한다.

# %% [markdown]
# ## 패키지 설치
#
# Tool loop에 필요한 LangGraph, OpenAI와 Tavily 통합을 설치한다. 이 셀은 외부 검색이나 유료 모델을 호출하지 않는다.

# %%
# %pip install -U langgraph langchain-openai langchain-tavily python-dotenv
# Out:
# Requirement already satisfied: langgraph in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (1.2.11)
# Requirement already satisfied: langchain-openai in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (1.5.1)
# Requirement already satisfied: langchain-tavily in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (0.2.18)
# Requirement already satisfied: python-dotenv in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (1.2.3)
# Requirement already satisfied: langchain-core<2,>=1.4.7 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (1.5.4)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.10.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai) (3.2.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: httpx2<3,>=2.7.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (2.10.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.70.0)
# Requirement already satisfied: httpcore2==2.10.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (2.10.0)
# Requirement already satisfied: truststore>=0.10 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (0.10.4)
# Requirement already satisfied: regex in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-tavily) (3.14.3)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from langchain-tavily) (1.3.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.24.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\leso0\miniforge3\envs\llm_env\Lib\site-packages (from tqdm>4->openai<4.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## OpenAI와 Tavily 인증 준비
#
# `.env` 또는 운영체제 환경 변수에서 필수 키를 불러온다. 값 자체는 출력하지 않고, LangSmith가 없을 때도 그래프의 핵심 경로는 유지한다.

# %%
import os
from dotenv import find_dotenv, load_dotenv

dotenv_path = find_dotenv(usecwd=True)
load_dotenv(dotenv_path, override=False)

if os.getenv("LANGSMITH_API_KEY"):
    os.environ.setdefault("LANGSMITH_TRACING", "true")
    os.environ.setdefault("LANGSMITH_PROJECT", "langgraph-tool-chat")

OPENAI_CHAT_MODEL = os.getenv("OPENAI_CHAT_MODEL", "gpt-5.6-luna")

# %% [markdown]
# ## Tavily Tool의 입력과 반환 구조
#
# Tavily(태빌리)는 AI 애플리케이션이 최신 웹 문서를 검색하도록 제공하는 검색 서비스이다.<br>
# `TavilySearch`는 이 서비스를 LangChain Tool 형식으로 감싼 객체이다.
#
# - `Tool`: 모델에 보여 줄 이름·설명·입력 규칙과 실제 Python 실행 기능을 함께 가진 객체이다.
# - `args_schema`: Tool이 받을 수 있는 인자 이름과 자료형을 정의한 입력 스키마이다. `TavilySearch`에서는 `query` 등의 값을 검사하고, `bind_tools()`가 모델에 전달할 함수 설명의 근거가 된다.
# - `invoke()` 입력: `query`가 담긴 딕셔너리이다.
# - `invoke()` 출력: 검색어와 `results` 목록 등이 담긴 딕셔너리이다.
#
# Agent에 연결하기 전에 직접 호출하면 Tavily 인증·입력 문제를 뒤의 모델 판단이나 그래프 연결 문제와 분리할 수 있다.

# %%
from langchain_tavily import TavilySearch

# 웹 검색 도구 (관련 내용 최대 2건 검색)
tavily_tool = TavilySearch(max_result=2)

# tavily 정상 동작 확인
tavily_tool.invoke({'query':'LangGraph에서 Node란 무엇인가?'})
# Out:
# {'query': 'LangGraph에서 Node란 무엇인가?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://databoom.tistory.com/entry/LangGraph-%EB%85%B8%EB%93%9Cnode%EC%99%80-%EC%97%A3%EC%A7%80edge',
#    'title': '[LangGraph] 노드(node)와 엣지(edge) - 인공지능 개발자 수다',
#    'content': '## 1. 노드 (Node)\n\n### 1.1.  노드 개념\n\n노드는 데이터를 입력받아 처리한 뒤 결과를 반환하는 실행 단위다.  \nLangGraph에서는 파이썬 함수나 Runnable 객체로 정의할 수 있다.  \n   \n특징\n\n 하나의 노드는 하나의 역할에 집중하는 것이 좋다.\n 입력과 출력은 State를 기반으로 한다.\n 노드의 이름은 고유해야 한다.\n\n### 1.2. 노드 만드는 법 기본\n\n#### 1.2.1. 함수로 만들기\n\n state 를 입력으로 받음\n\nreturn 규칙\n\n 반드시 dict 형식으로 반환해야 하며, key는 State에서 정의한 필드와 일치해야 함.\n LangGraph는 이 dict를 기존 state에 \\\\병합(merge)\\\\한다.\n 필요한 필드만 반환해도 되고, 나머지는 이전 state 값이 유지된다.\n\ngraph에 노드 추가하기 [...] # 인공지능 개발자 수다\n\n인공지능 개발자 수다(유튜브 바로가기) 자세히보기\n\n자연어처리/LangGraph\n\n## [LangGraph] 노드(node)와 엣지(edge)\n\nSuda\\_777 2025. 8. 9. 22:40\n\n목차\n\n반응형\n\nlanggraph 버전: 0.6.4  \n내용 출처 : LangGrapn Docs\n\nLangGraph\n\nLangGraph Trusted by companies shaping the future of agents – including Klarna, Replit, Elastic, and more – LangGraph is a low-level orchestration framework for building, managing, and deploying long-running, stateful agents. Get started Install LangGr\n\nlangchain-ai.github.io\n\n## 1. 노드 (Node)',
#    'score': 0.89279664,
#    'raw_content': None,
#    'id': '920833-00'},
#   {'url': 'https://www.ibm.com/kr-ko/think/topics/langgraph',
#    'title': 'LangGraph란 무엇인가요?',
#    'content': '순환 그래프: 순환 그래프는 순환을 하나 이상 포함하는 그래프로, 에이전트 런타임에 필수적입니다. 이는 동일한 노드에서 시작하고 끝나면서 루프를 형성하는 경로가 그래프 안에 존재한다는 의미입니다. 복잡한 워크플로에는 순환 종속성이 포함되어 있는 경우가 많으며, 루프의 이전 단계에 따라 다음 단계의 결과가 달라집니다.\n\n노드: LangGraph에서 노드는 AI 워크플로 안에 있는 개별 구성 요소 또는 에이전트를 나타냅니다. 노드는 특정 방식으로 상호 작용하는 "행위자"라고 볼 수 있습니다. 예를 들어 툴 호출을 위한 노드를 추가할 땐 ToolNode를 사용할 수 있습니다. 또 다른 예로, 다음 노드는 현재 노드 다음에 실행될 노드를 가리킵니다.\n\n엣지: 엣지는 현재 상태에 따라 다음에 실행할 노드를 결정하는 Python 내의 함수입니다. 엣지는 조건부 분기 또는 고정적인 전환일 수 있습니다.\n\n#### 툴 [...] ## LangGraph 확장 방법\n\nLangGraph는 그래프 기반 아키텍처를 사용하여 사용자가 효율성을 저하시키지 않으면서 인공 지능 워크플로를 확장하도록 지원합니다. LangGraph는 노드 간의 복잡한 관계를 모델링하여 의사 결정을 향상시킵니다. 즉, AI 에이전트를 사용하여 이 노드들의 과거 행동과 피드백을 분석합니다. LLM의 세계에서는 이 프로세스를 성찰(reflection)이라고 합니다.\n\n의사 결정: LangGraph는 노드 간의 복잡한 관계를 모델링하여 보다 효과적인 의사 결정 시스템을 구축하기 위한 프레임워크를 제공합니다.\n\n유연성 향상: 개발자가 새로운 구성 요소를 통합하고 기존 워크플로를 조정할 수 있는 오픈 소스 특성과 모듈식 디자인을 갖췄습니다. [...] #### 툴\n\nRAG: 검색 증강 생성(RAG)은 관련 문서를 검색하고 답변 생성을 위한 인풋으로 사용해서, LLM의 기능을 외부 소스의 컨텍스트 정보와 결합합니다.\n\n워크플로: 워크플로는 AI 워크플로를 정의하는 노드 상호작용의 시퀀스입니다. 노드를 워크플로에 배열하면 개별 구성 요소의 강점을 사용하는 좀 더 복잡하고 동적인 워크플로를 만들 수 있습니다.\n\nAPI: LangGraph는 사용자가 프로그래밍 방식으로 구성 요소와 상호 작용하게 하는 API 세트를 제공합니다. 사용자는 API 키를 사용하고, 새 노드를 추가하고, 기존 워크플로를 수정하고, AI 워크플로에서 데이터를 검색할 수 있습니다.',
#    'score': 0.8923472,
#    'raw_content': None,
#    'id': '4a3b09-01'},
#   {'url': 'https://tilnote.io/books/68156a4ebaa37b745385c23b/68156a79baa37b745385c298',
#    'title': '3장: LangGraph의 핵심 구성요소 – 노드, 엣지, 상태 관리 - LangGraph 활용 가이드',
#    'content': "노드는 LangGraph 워크플로우에서 하나하나의 작업 구간을 가리킨다. 말하자면 정보 추출, 외부 도구 호출, LLM 응답 생성 등 실제로 '일'이 이루어지는 지점으로, 파이썬 함수나 지정 작업 체인으로 정의한다. 각 노드는 입력으로 현재 상태 정보를 받고, 자신만의 작업 뒤에 업데이트된 상태를 돌려준다. 즉, 데이터의 변환 지점이자 다양한 프로세스의 교차로라고 할 수 있다.\n\n## 엣지: 흐름과 분기점 설계\n\n엣지는 그래프 내에서 노드 사이의 흐름을 결정하는 연결선이다. 엣지는 단순하게 다음 작업 노드를 가리킬 수도 있고, 조건에 따라 서로 다른 경로를 지정할 수도 있다. 예를 들어 특정 분석 결과에 따라 다른 처리 로직으로 이동하게끔 조건부 분기를 만들 수 있다. 반복 구조나 순환 경로 또한 엣지 설계만으로 충분히 표현할 수 있다.\n\n## 상태 관리: 데이터와 문맥의 토대 [...] LangGraph에서는 문맥과 작업 중간 결과 모두를 하나의 상태 객체에서 다룬다. 보통 TypedDict나 Pydantic 모델 형태로 구조화하며, 각 노드 간 데이터를 공유하고 업데이트하는 창구 역할을 한다. 이 상태는 초기 입력, 작업별 중간산출물, 사용자 컨텍스트 등 운영에 필요한 대부분의 정보를 포괄한다. 상태 관리를 철저히 하는 것은 워크플로우가 예측 가능하고 안정적으로 돌아가는 핵심 비결이다.\n\n## 실제 활용법과 팁\n\n워크플로우 설계 초기에는 진행 경로가 단순해 보일 수 있지만, 요구가 복잡해질수록 여러 노드와 분기, 반복 구조가 빈번히 나타난다. 각 노드가 상태 객체에 자신의 결과나 작업 로그를 누적하는 식으로 설계하면, 전체 프로세스의 가시성과 확장성이 크게 높아진다. 조건부 엣지나 반복 흐름도 명시적으로 정의할 수 있으니, 분기와 병렬 작업이 많은 대규모 시나리오에도 효과적이다. [...] LangGraph의 진가는 상태, 노드, 엣지 세 요소의 치밀한 조합에서 드러난다. 각 요소의 역할과 연결 방식을 확실히 이해하고, 상황에 따라 유연하게 재구성하는 것이 LangGraph 숙련자의 첫걸음이다.\n\n이 페이지가 도움이 되었다면 링크를 공유해보세요.\n\n카카오로 공유하기\n\n페이스북 공유하기\n\n트위터로 공유하기\n\nurl 복사하기",
#    'score': 0.8627572,
#    'raw_content': None,
#    'id': '239616-02'},
#   {'url': 'https://bcho.tistory.com/1486',
#    'title': '고급 Agent를 위한 Langgraph 개념 이해 #2 - Node',
#    'content': '# 조대협의 블로그\n\n빅데이타 & 머신러닝/생성형 AI (ChatGPT etc)\n\n## 고급 Agent를 위한 Langgraph 개념 이해 #2 - Node\n\nTerry Cho 2025. 7. 8. 16:42\n\n# 2. Node\n\nNode는 State 정보를 활용해서, State 정보를 변경하거나 action을 취하는 그래프내의 함수이다. \n\n함수내에서는 LLM 모델을 실행해서 질문에 대한 정답을 찾거나 , Tool 등을 이용해서 Action을 취하거나, 또는 RAG를 통해서 질문에 필요한 추가 컨택스트 정보를 검색해와서 State에 저장해서 다음 Node에서 LLM이 답변에 활용할 수 있도록 한다. [...] 예를 들어 web\\_search,chat 이라는 Node가 있을때, web\\_search Node에서는 Google 검색을 이용하여, 질문에 필요한 추가 정보를 검색해서 State에 저장한후, 다음 chat 노드에서 해당 State에 저장된 Context 정보를 리턴하는 식으로 구현이 된다. \n\nNode는 Python function으로 정의되며, 입력 parameter는 State 타입을 사용하며, 리턴은 State 정보의 스키마를 따르는 Dictionary나 TypedDict를 데이터 형으로 사용한다. \n\n아래 그림은 노드를 Pseudo 코드로 간단하게 구현해 놓은 예제이다. [...] 별도의 벡터 데이터베이스를 설정한 후에, 캐쉬에 저장되는 키 값에 대한 임베딩 벡터를 벡터데이터 베이스에 저장하고, 새롭게 질의된 문장의 임베딩 값을 계산해서, 벡터데이터베이스에 기 저장된 문장의 임베딩값과 비교한다. \n\n아래 코드는 벡터데이터베이스에서 새롭게 질의된 문장과 유사한 문장을 검색하는 코드이다. \n\n```\nsearch_results = vector_store.similarity_search_with_score(question, k=1)\n```\n\n만약에 검색된 결과가 SIMLARITY\\_THRESHOLD (기준값) 이상이면, 기존에 저장된 질문을 캐쉬 값으로 리턴한다.',
#    'score': 0.83932644,
#    'raw_content': None,
#    'id': '2ec83c-03'},
#   {'url': 'https://lsjsj92.tistory.com/696',
#    'title': '꿈 많은 사람의 이야기',
#    'content': "상태 (State): 그래프의 '메모리'입니다. 그래프의 각 단계를 거치면서 데이터가 어떻게 변하고 유지되는지를 정의하는 객체입니다. 대화 기록, 중간 결과, 사용자 정보 등 에이전트가 작업을 수행하는 동안 기억해야 할 모든 정보가 이 상태에 담깁니다. 보통 파이썬의 TypedDict를 사용하여 명확한 구조로 정의합니다.\n 노드 (Nodes): 그래프의 '작업 단위'입니다. 특정 작업을 수행하는 Python 함수라고 생각할 수 있습니다. 노드는 현재의 상태(State)를 입력받아, LLM을 호출하거나 도구를 사용하는 등의 작업을 처리한 뒤, 변경된 상태를 반환합니다.\n 엣지 (Edges): 노드와 노드를 연결하는 '경로'입니다. 정보와 제어 흐름이 어떤 순서로 이어질지를 결정합니다.\n\n## 예제 코드로 LangGraph 작동 방식 이해하기 [...] 관리 메뉴\n\n 글쓰기\n 방명록\n RSS\n 관리\n\n## 꿈 많은 사람의 이야기\n\n## 랭그래프(LangGraph)란? LangGraph의 개념과 사용 방법 예제(example) 본문\n\n인공지능(AI)/AI Agent\n\n### 랭그래프(LangGraph)란? LangGraph의 개념과 사용 방법 예제(example)\n\n이수진의 블로그 2025. 7. 27. 16:29\n\n반응형\n\n## 포스팅 개요\n\n이번 포스팅에서는 랭체인(LangChain) 생태계의 라이브러리인 랭그래프(LangGraph)에 대해서 알아봅니다. LangGraph란 무엇인지 알아보고, LangGraph를 사용하여 LLM 애플리케이션의 로직과 흐름을 명확하게 제어하는 방법을 알아봅니다. 특히 LangGraph의 핵심 구성 요소인 상태(State), 노드(Node), 엣지(Edge)에 대해 자세히 살펴보고, LLM을 연동하여 간단한 챗봇 에이전트(Agent)를 만들어보는 예제 코드를 살펴봅니다. [...] ```\nfrom typing import List, Annotated from typing_extensions import TypedDict from langchain_core.messages import AnyMessage class AgentState(TypedDict): # 'messages'는 대화 기록을 저장하는 리스트입니다. messages: Annotated[List[AnyMessage], lambda x, y: x + y] turn_count: int\n```\n\n messages: 사용자와 AI의 대화 기록을 list 형태로 계속 축적해 나갑니다. Annotated와 lambda 함수 lambda x, y: x + y는 LangGraph가 새로운 메시지를 기존 리스트에 자동으로 더해주도록 하는 편리한 기능입니다.\n turn\\_count: 대화 턴 수를 기록하는 정수 값입니다.\n\n### 3. 에이전트 노드(Node) 정의",
#    'score': 0.79732054,
#    'raw_content': None,
#    'id': '3ec656-04'}],
#  'response_time': 0.0,
#  'request_id': 'cf7d9cf9-83d9-45eb-a772-981734f7ee47'}

# %% [markdown]
# ## Tool 스키마를 Chat Model에 연결하기
#
# ### 호출 전에 넣는 `tools`
#
# - `tools`: 모델이 선택할 수 있도록 전달하는 Tool 객체 목록이다.
# - `bind_tools(tools)`: 각 Tool의 이름·설명·`args_schema`를 모델 요청에 포함한 새 Runnable을 만든다.
#
# ### 호출 뒤에 나오는 `tool_calls`
#
# - `tool_calls`: 모델이 `tools`를 보고 만든 실행 요청 목록이다.
#     - 이름이 비슷하지만 Tool 객체 목록이 아니라 **모델의 출력**이며, 이 단계에서는 Python Tool이 아직 실행되지 않았다.
#     - 실제 실행은 뒤의 Tool Node가 맡는다.

# %%
from langchain_openai import ChatOpenAI

# 1. llm 모델 객체 생성
llm = ChatOpenAI(
    model=OPENAI_CHAT_MODEL,
    use_responses_api=True,
)

# 2. llm에게 전달할 tool 목록 생성
tools = [tavily_tool]

# 3. llm과 tool 목록이 연결된 새 Runnable 생성
llm_with_tools = llm.bind_tools(tools)

print(type(llm).__name__, type(llm_with_tools).__name__)
# Out:
# ChatOpenAI _ChatModelBinding

# %% [markdown]
# ## Tool 호출 루프를 완성할 네 구성 요소
#
# 여기까지 만든 `llm_with_tools`는 Tool의 이름·설명·입력 스키마를 알고 **실행 요청을 작성할 수 있는 모델**이다. `bind_tools()`는 Tool을 모델에 알려 줄 뿐 Tavily를 실행하지 않는다.
#
# 모델의 요청을 실제 실행하고 그 결과를 다시 모델에게 전달하려면 다음 네 구성 요소가 필요하다.
#
# 1. `State`: 질문·Tool 요청·Tool 결과·최종 답변을 이어 주는 공유 메시지 규칙이다.
# 2. `chatbot`: State를 읽어 일반 답변 또는 `tool_calls`가 담긴 `AIMessage`를 만드는 Node이다.
# 3. `ToolNode`: `tool_calls`를 읽어 실제 Tool을 실행하고 `ToolMessage`를 만드는 Node이다.
# 4. `tools_condition`: 최신 `AIMessage`에 Tool 요청이 있는지 보고 다음 경로를 정하는 route function이다.
#
# ```text
# HumanMessage → chatbot → AIMessage → tools_condition
#                          ├─ tool_calls 있음 → ToolNode → ToolMessage → chatbot
#                          └─ tool_calls 없음 → END
# ```
#
# 다음 네 셀에서는 이 부품을 **정의만** 하므로 화면 출력이나 외부 호출이 발생하지 않는다. 뒤의 `네 구성 요소를 Tool 호출 루프로 조립하기`에서 `StateGraph`에 등록하고 `compile()`한 뒤, `graph.invoke()`를 호출할 때 하나의 반복 구조로 동작한다.
#
# ### 1. 대화 이력을 합칠 State 규칙 정의하기
#
# `State`는 Node 사이에서 공유하는 데이터 구조이다. 이 셀에서는 메시지를 직접 저장하지 않고, 그래프 실행 중 새 message를 기존 목록에 합치는 규칙을 선언한다.
#
# - 저장 대상: `HumanMessage`(질문), `AIMessage`(답변 또는 Tool 요청), `ToolMessage`(Tool 결과)이다.
# - 실행 시 입력: 기존 `messages`와 Node가 반환한 새 message이다.
# - 변환: `add_messages` reducer가 두 값을 실행 순서대로 합친다.
# - 출력: 다음 Node가 읽을 수 있는 갱신된 `messages`이다.
# - 다음 사용처: Tool 결과가 추가된 뒤 `chatbot`이 이전 질문과 요청까지 함께 읽는다.

# %%
from typing import Annotated, TypedDict

from langchain_core.messages import AnyMessage
from langgraph.graph.message import add_messages

class State(TypedDict):
    messages: Annotated[list[AnyMessage], add_messages]

# %% [markdown]
# ### 2. 모델의 다음 행동을 정하는 chatbot Node 만들기
#
# `chatbot`은 현재 State의 전체 `messages`를 `llm_with_tools`에 전달하는 Node이다. 모델은 일반 답변 또는 `tool_calls`가 담긴 `AIMessage`를 만들지만, 이 Node가 Tool을 직접 실행하지는 않는다.
#
# - 입력: `HumanMessage`·`AIMessage`·`ToolMessage`가 누적된 현재 State이다.
# - 변환: 모델이 지금 답할지 Tool 실행을 요청할지 결정한다.
# - 출력: 새 `AIMessage` 하나이다.
# - 다음 사용처: `add_messages`가 State에 합치고 `tools_condition`이 다음 경로를 판단한다.
#
# 첫 호출에서는 Tool 요청을 만들 수 있고, Tool 결과가 State에 추가된 뒤 다시 호출되면 그 결과를 근거로 최종 답변을 만들 수 있다. 이 셀은 함수 정의 단계이므로 모델 API는 아직 호출하지 않는다.

# %%
def chatbot(state:State) -> dict:
    # State의 메시지를 tool이 묶여있는 llm에 전ㄱ달 -> tool 사용 조건은 아래에서 정의할 예정
    response = llm_with_tools.invoke(state['messages'])
    return {'messages': [response]}

# %% [markdown]
# ### 3. Tool 요청을 실제 실행하는 Tool Node 만들기
#
# `chatbot`이 만든 `tool_calls`는 **실행 요청**일 뿐 실제 검색 결과가 아니다. `ToolNode`는 요청의 Tool 이름과 인자를 읽고 허용된 Python Tool을 실행한 뒤, 결과를 `ToolMessage`로 바꾸는 Node이다.
#
# ```text
# tool_calls의 name·args·id
#         ↓ 이름으로 Tool 선택
# tool.invoke(args)
#         ↓ 결과와 같은 호출 ID 연결
# ToolMessage(content, tool_call_id=id)
# ```
#
# - 입력: 최신 `AIMessage.tool_calls`의 `name`·`args`·`id`이다.
# - 변환: `name`으로 허용된 Tool을 찾고 `tool.invoke(args)`로 실행한다.
# - 출력: 실행 결과와 같은 호출 ID를 담은 `ToolMessage` 목록이다.
# - 다음 사용처: `add_messages`가 결과를 State에 합치고 `tools → chatbot` Edge가 모델로 돌려보낸다.
#
# 이 Node는 Tool 요청의 유무를 판단하지 않는다. 뒤의 `tools_condition`이 `tool_calls`가 있을 때만 이 Node로 보낸다. 내부 원리를 확인하기 위해 직접 구현하며, 노트북 마지막에는 같은 역할의 LangGraph 기본 제공 `ToolNode`로 교체한다.

# %%
import json

from langchain_core.messages import ToolMessage

class ToolNode:
    '''
    AIMessage.tool_calls를
    허용된 python tool(함수) 결과로 바꾸는 node
    '''

    # 1. 전달 받은 tool 목록을 {tool 이름 : 실제 tool 함수} 형태의 dict로 변환
    def __init__(self, tools):
        self.tools_by_name = {
            tool.name: tool for tool in tools
        }

    # 2. __call__(): 객체를 함수처럼 호출할 수 있게 하는 메서드
    # ex) tool_node = ToolNode(tools)
    #     tool_node.__call() == tool_node()
    def __call__(self, state:State):
        # 요청 읽기 : State에 messages가
        # -> 없으면 []
        # -> 있으면 마지막 message를 tool 요청으로 사용
        messages = state.get('messages', [])

        if not messages:
            raise ValueError('State에 messages가 없습니다')

        # state의 마지막 메시지
        request_message = messages[-1]

        # 3. Tool 실행 : 각 tool_calls의 name, args, id를 차례대로 처리
        outputs = [] # tool 요청 결과를 저장할 list

        for tool_call in request_message.tool_calls:
            tool_name = tool_call['name']

            if tool_name not in self.tools_by_name:
                raise ValueError(f'허용되지 않은 Tool 요청입니다. : {tool_name}')

            # args : args schema 검사를 거쳐 Tool에 입력할 값 dict
            tool_result = self.tools_by_name[tool_name].invoke(tool_call['args'])

            # 4. tool 결과를 ToolMessage로 변환하여 outputs에 누적
            outputs.append(
                ToolMessage(
                    # 결과를 만든 tool의 이름
                    name=tool_name,
                    # Tool 결과(dict)를 json으로 변환
                    content=json.dumps(
                        tool_result,
                        ensure_ascii=False,
                    ),
                    # tool 요청 id
                    tool_call_id = tool_call['id']
                )
            )

        # 5. State 갱신값을 반환
        # -> ToolNode 종료 후 add_messages 가 State['messages'] 제일 뒤에 outputs를 추가(갱신작업)
        return {'messages':outputs}

# 6. ToolNode 노드 생성
tool_node = ToolNode(tools)

# %% [markdown]
# ### 4. Tool 실행 여부를 판단하는 route function 만들기
#
# `tools_condition`은 Conditional Edge 자체가 아니라, 현재 State를 읽고 **다음 목적지 label만 반환하는 함수**이다.
#
# - 입력: `chatbot`이 방금 추가한 최신 `AIMessage`이다.
# - 변환: `tool_calls` 목록이 비어 있는지 확인한다.
# - 출력: 요청이 있으면 `"tools"`, 없으면 `END`를 반환한다.
# - 다음 사용처: `add_conditional_edges()`가 반환값을 실제 목적지와 연결한다.
#
# 이 함수는 Tool을 실행하거나 State를 수정하지 않는다. 실제 Conditional Edge는 뒤에서 `add_conditional_edges()`가 반환값과 목적지를 연결할 때 만들어진다. 이 셀도 함수 정의 단계이므로 화면 출력은 없다.

# %%
from langgraph.graph import END

# 마지막 AIMessage의 tool_calls 유무로 다음 경로를 결정하는 route Function 정의
def tools_condition(state:State):
    # 1. 분기를 판단할 message channel 읽기
    messages = state.get('messages', [])
    if not messages:
        raise ValueError('조건을 판정할 messages가 존재하지 않음')

    # 2. chatbot Node에서 추가한 마지막 메시지(AIMessage) 꺼내기
    last_message = messages[-1]

    # 3. 마지막 메시지가 'tool_calls' 인지 확인
    has_tool_calls = bool(
        # last_message에서 'tool_calls' 얻어오기, 없으면 []
        getattr(last_message, 'tool_calls', [])
    )

    print(f'has_tool_calls = {has_tool_calls}')

    # 4. hass_tool_calls가 True이면 Node Label, False이면 END 반환
    return 'tools' if has_tool_calls else END

# %% [markdown]
# ## 네 구성 요소를 Tool 호출 루프로 조립하기
#
# 앞의 네 셀은 부품의 역할만 정의했다. 이제 `StateGraph(State)`에 두 Node를 등록하고, route function의 반환값을 실제 목적지에 연결한다.
#
# - `State` → `StateGraph(State)`: 모든 Node가 공유할 message 규칙이다.
# - `chatbot` → `add_node("chatbot", chatbot)`: 다음 `AIMessage`를 만드는 Node이다.
# - `tool_node` → `add_node("tools", tool_node)`: Tool 요청을 실행하는 Node이다.
# - `tools_condition` → `add_conditional_edges(...)`: `tools` 또는 `END` 경로를 선택한다.
# - Tool 결과 재입력 → `add_edge("tools", "chatbot")`: `ToolMessage`를 모델이 다시 읽게 한다.
#
# ### `add_conditional_edges()`의 세 인자 읽기
#
# `add_conditional_edges()`는 **특정 Node가 끝난 뒤 route function을 실행하고, 반환값에 맞는 다음 목적지로 이동하라**는 규칙을 등록한다. 이 코드를 작성하는 시점에는 분기나 Tool 실행이 일어나지 않고, 뒤에서 `graph.invoke()`가 실행될 때 사용된다.
#
# - 첫 번째 인자 `"chatbot"`: 어느 Node가 끝난 뒤 분기할지 지정한다.
# - 두 번째 인자 `tools_condition`: 현재 State를 받아 `"tools"` 또는 `END`를 반환한다.
# - 세 번째 인자 `path_map`: route function의 **반환값을 실제 목적지로 바꾸는 딕셔너리**이다.
#   - 왼쪽 값: `tools_condition`이 반환한 값이다.
#   - 오른쪽 값: LangGraph가 실제로 이동할 Node 이름 또는 종료 지점이다.
#
# ```text
# chatbot 실행 완료
#     ↓
# tools_condition(state)
#     ├─ "tools" 반환 → path_map["tools"] → "tools" Node 실행
#     └─ END 반환     → path_map[END]     → 그래프 종료
# ```
#
# 따라서 `{"tools": "tools", END: END}`는 `"tools"`가 나오면 이름이 `"tools"`인 Node로 이동하고, `END`가 나오면 실행을 끝내라는 분기표이다. 현재는 반환값과 목적지 이름이 같지만, 둘의 역할을 구분해 보여 주기 위해 명시적으로 작성한다.
#
# `StateGraph`는 State 스키마를 기준으로 Node와 Edge를 등록하는 builder이다. 등록만으로 실행되지는 않으며 `compile()`해야 호출 가능한 그래프가 된다.
#
# ![LangGraph 공식 Agent Workflow](https://cdn.jsdelivr.net/gh/goat-skn-ai/image-repo@7f008bd902003af9b0138e956af0be37ffa7a9ff/08_llm/08_langgraph/01_langgraph_basics/langgraph_official_agent_loop.png)
#
# 1. `In`: 뒤의 실행 셀에서 `initial_state`에 담은 사용자 질문이 들어온다.
# 2. `LLM call`: `chatbot` Node가 답변 또는 `AIMessage.tool_calls`를 만든다.
# 3. `action`: Tool 요청이 생기면 `tools_condition`이 `tools` 경로를 고른다. 요청이 없으면 `END`를 고른다.
# 4. `Tool`: `tool_node`가 요청을 실행하고 `ToolMessage`를 만든다.
# 5. `feedback`: `add_messages`가 결과를 State에 합치고 `tools → chatbot` Edge가 모델의 다음 판단으로 돌려보낸다.
# 6. `Out`: 마지막 `AIMessage.tool_calls`가 비면 `END`에서 최종 State를 반환한다.
#
# 그림의 feedback 화살표가 코드의 반복 Edge이다. 모델이 Tool을 더 요청하면 `chatbot → tools → chatbot`이 반복된다. 공식 그림의 `Tool → Out`은 일반화된 표현이다. 이 실습에는 `tools → END` Edge가 없으므로 Tool 결과는 항상 `chatbot`으로 돌아가며, 재호출된 `chatbot`이 Tool 요청 없는 최종 `AIMessage`를 만들 때 Conditional Edge가 `END`를 선택한다.
#
# > 이미지 출처: [LangChain 공식 문서 - Workflows and agents](https://docs.langchain.com/oss/python/langgraph/workflows-agents)

# %%
from langgraph.graph import END, START, StateGraph

# 1. Builder 생성
workflow = StateGraph(State)

# 2. Node 등록
workflow.add_node('chatbot', chatbot)
workflow.add_node('tools', tool_node)

# 3. Edge 연결
workflow.add_edge(START, 'chatbot')
workflow.add_edge('tools', 'chatbot')

# 4. add_conditional_edges(source, path, path_map)
# - chatbot 실행 뒤 분기 규칙을 등록
workflow.add_conditional_edges(
    'chatbot',  # 어떤 노드가 끝난 뒤 분기할 것인가?
    tools_condition, # 다음 목적지를 판단할 함수
    {
        'tools':'tools', # tools_condition 반환값에 따라서
        END:END,        # 연결될 실제 노드 매핑
    }
)

# 5. compile() : 실행 가능한 상태로 변경
graph = workflow.compile()
display(graph)

# %% [markdown]
# ## 검색이 필요한 질문의 message 흐름 확인
#
# `invoke(initial_state)`는 LLM을 한 번만 호출하는 메서드가 아니다. `START`부터 `END`까지 이동하며 조건에 따라 chatbot과 tools Node를 여러 번 실행한 뒤 최종 State를 반환한다.
#
# 검색이 한 번 실행되면 `messages`는 보통 다음 순서가 된다. 모델이 추가 검색을 요청하면 가운데 두 단계가 반복될 수 있다.
#
# ```text
# HumanMessage
# → AIMessage(tool_calls: name·args·id)
# → ToolMessage(tool_call_id: 같은 id)
# → 최종 AIMessage(tool_calls: [])
# ```
#
# 전체 State에는 검색 본문과 응답 block도 들어 있다. 아래 코드는 경로를 쉽게 읽도록 message 종류, Tool 이름과 호출 ID만 `list[dict]`로 요약한다.

# %%
from langchain_core.messages import HumanMessage

def summarize_messages(messages: list[AnyMessage]) -> list[dict]:
    """message 본문을 제외하고 종류와 Tool 호출 연결 정보만 반환"""

    return [
        {
            "message_type": message.type,  # human·ai·tool 중 message 종류
            "tool_calls": [  # AIMessage가 요청한 Tool 이름과 호출 ID 목록
                {"name": tool_call["name"], "id": tool_call["id"]}
                for tool_call in getattr(message, "tool_calls", [])
            ],
            # ToolMessage가 아니면 연결할 호출 ID가 없으므로 None을 사용한다.
            "tool_call_id": getattr(message, "tool_call_id", None),
        }
        for message in messages
    ]

# 1. 입력 준비
user_input = 'LangGraph의 Node외 Edge를 설명하고, 필요하면 검색 Tool을 사용해줘'
initial_state = {
    'messages':[HumanMessage(content=user_input)]
}

# 2. 실행 후 결과 반환 받기
final_state = graph.invoke(initial_state) # START -> END

# 3. 결과 출력
trace_summary = summarize_messages(final_state['messages'])
display(trace_summary)
# Out:
# has_tool_calls = True
# has_tool_calls = False
# [{'message_type': 'human', 'tool_calls': [], 'tool_call_id': None},
#  {'message_type': 'ai',
#   'tool_calls': [{'name': 'tavily_search',
#     'id': 'call_AslhswIT5tn50lMlJNrbL2HS'}],
#   'tool_call_id': None},
#  {'message_type': 'tool',
#   'tool_calls': [],
#   'tool_call_id': 'call_AslhswIT5tn50lMlJNrbL2HS'},
#  {'message_type': 'ai', 'tool_calls': [], 'tool_call_id': None}]

# %% [markdown]
# ## 최종 AIMessage의 content 구조 확인
#
# 마지막 `AIMessage`는 Tool 결과를 읽고 만든 최종 응답이다. Responses API에서는 응답을 다룰 때 다음 세 값을 구분해야 한다.
#
# - `content`: 공급자가 반환한 원본 content이다. 문자열일 수도 있고 block 목록일 수도 있다.
# - `content_blocks`: 공급자별 content를 공통 block 목록으로 정규화한 값이다. block의 종류와 구조를 확인할 때 사용한다.
# - `text`: text block만 모은 문자열이다. 화면 렌더링이나 일반 문자열 처리를 할 때 사용한다.
#
# 아래 코드는 `content_blocks`에서 사용자에게 공개할 `type='text'` block의 `type`과 `text`만 선택한다.

# %%
final_message = final_state['messages'][-1]

public_content_block = [
    {
        'type':block['type'],
        'text': block.get('text','')
    }
    for block in final_message.content_blocks
    if block.get('type') == 'text'
]

print(public_content_block)
# Out:
# [{'type': 'text', 'text': '# LangGraph의 Node와 Edge\n\nLangGraph에서 워크플로는 크게 다음 세 가지로 구성됩니다.\n\n```text\nState + Node + Edge\n```\n\n- **State**: 노드 사이에서 공유되는 데이터\n- **Node**: 실제 작업을 수행하는 함수\n- **Edge**: 다음에 실행할 노드를 결정하는 연결 관계\n\nLangGraph는 일반적인 DAG뿐 아니라, 조건 분기·반복·병렬 실행·Human-in-the-loop 같은 복잡한 흐름을 그래프로 표현할 수 있습니다.\n\n---\n\n## 1. Node란?\n\n**Node는 상태를 입력받아 작업을 수행하고, 상태 변경 내용을 반환하는 함수**입니다.\n\n노드는 다음과 같은 일을 할 수 있습니다.\n\n- LLM 호출\n- 사용자 입력 처리\n- 외부 API 호출\n- 데이터베이스 조회\n- 도구 호출\n- 결과 검증\n- 조건 판단\n- 다른 에이전트 실행\n\n노드는 반드시 LLM일 필요는 없습니다. 단순한 Python 함수도 노드가 될 수 있습니다.\n\n### 기본 형태\n\n```python\nfrom typing_extensions import TypedDict\nfrom langgraph.graph import StateGraph, START, END\n\n\nclass State(TypedDict):\n    question: str\n    answer: str\n\n\ndef answer_node(state: State):\n    answer = f"질문을 처리했습니다: {state[\'question\']}"\n\n    return {\n        "answer": answer\n    }\n```\n\n`answer_node`는 `State`를 입력받고, 변경할 상태의 일부를 딕셔너리로 반환합니다.\n\n---\n\n## 2. Node는 전체 State를 반환하지 않아도 된다\n\n노드는 전체 상태를 다시 반환할 필요가 없습니다.\n\n```python\ndef answer_node(state: State):\n    return {\n        "answer": "답변입니다."\n    }\n```\n\n이 경우 기존 `question`은 유지되고 `answer`만 업데이트됩니다.\n\n다만 상태 필드별로 값이 어떻게 합쳐지는지는 **reducer** 설정에 따라 달라질 수 있습니다.\n\n예를 들어 기본적으로는 다음처럼 값이 덮어써집니다.\n\n```python\nclass State(TypedDict):\n    message: str\n```\n\n반면 리스트에 결과를 누적하고 싶다면 reducer를 사용할 수 있습니다.\n\n```python\nimport operator\nfrom typing import Annotated\nfrom typing_extensions import TypedDict\n\n\nclass State(TypedDict):\n    logs: Annotated[list[str], operator.add]\n```\n\n이 경우 여러 노드가 다음과 같이 반환하면:\n\n```python\nreturn {"logs": ["node A completed"]}\n```\n\n기존 리스트에 새로운 값이 추가됩니다.\n\n---\n\n## 3. Node 등록하기\n\nNode를 그래프에 등록하려면 `add_node()`를 사용합니다.\n\n```python\nbuilder = StateGraph(State)\n\nbuilder.add_node("answer", answer_node)\n```\n\n첫 번째 인자는 노드의 이름이고, 두 번째 인자는 실행할 함수입니다.\n\n최근 LangGraph에서는 함수 이름을 그대로 사용해 다음과 같이 등록할 수도 있습니다.\n\n```python\nbuilder.add_node(answer_node)\n```\n\n이 경우 함수 이름인 `"answer_node"`가 노드 이름으로 사용됩니다.\n\n---\n\n# 4. Edge란?\n\n**Edge는 한 노드에서 다음 노드로 실행 흐름을 연결하는 선**입니다.\n\n```text\nNode A → Node B\n```\n\nNode가 작업을 담당한다면, Edge는 **실행 순서와 분기 흐름**을 담당합니다.\n\n일반적인 Edge는 다음과 같이 정의합니다.\n\n```python\nbuilder.add_edge("node_a", "node_b")\n```\n\n이는 다음 의미입니다.\n\n> `node_a` 실행이 끝나면 `node_b`를 실행하라.\n\nEdge를 통해 상태가 직접 복사되는 것은 아니지만, 모든 노드는 기본적으로 같은 Graph State를 공유합니다.\n\n---\n\n## 5. START와 END\n\nLangGraph에는 특별한 두 개의 가상 노드가 있습니다.\n\n### `START`\n\n그래프 실행의 시작점을 나타냅니다.\n\n```python\nbuilder.add_edge(START, "answer")\n```\n\n의미는 다음과 같습니다.\n\n```text\n그래프 시작 → answer 노드\n```\n\n### `END`\n\n그래프 실행 종료를 나타냅니다.\n\n```python\nbuilder.add_edge("answer", END)\n```\n\n의미는 다음과 같습니다.\n\n```text\nanswer 노드 → 그래프 종료\n```\n\n`START`와 `END`는 일반적인 작업 노드가 아니라, 그래프의 시작과 끝을 표현하는 특수한 지점입니다. 공식 문서에서도 `START`는 사용자 입력을 그래프에 전달하는 시작 노드, `END`는 종료 지점으로 설명됩니다.  \n[LangGraph Graph API 공식 문서](https://docs.langchain.com/oss/python/langgraph/graph-api)\n\n---\n\n# 6. 가장 간단한 전체 예제\n\n```python\nfrom typing_extensions import TypedDict\nfrom langgraph.graph import StateGraph, START, END\n\n\nclass State(TypedDict):\n    question: str\n    answer: str\n\n\ndef answer_node(state: State):\n    return {\n        "answer": f"\'{state[\'question\']}\'에 대한 답변입니다."\n    }\n\n\nbuilder = StateGraph(State)\n\n# Node 등록\nbuilder.add_node("answer", answer_node)\n\n# Edge 연결\nbuilder.add_edge(START, "answer")\nbuilder.add_edge("answer", END)\n\n# 그래프 컴파일\ngraph = builder.compile()\n\n# 실행\nresult = graph.invoke({\n    "question": "LangGraph란 무엇인가?"\n})\n\nprint(result)\n```\n\n실행 흐름은 다음과 같습니다.\n\n```text\n입력\n  ↓\nSTART\n  ↓\nanswer_node\n  ↓\nEND\n  ↓\n최종 State 반환\n```\n\n---\n\n# 7. 일반 Edge\n\n가장 단순한 Edge는 항상 같은 다음 노드로 이동합니다.\n\n```python\nbuilder.add_edge("retrieve", "generate")\n```\n\n흐름은 다음과 같습니다.\n\n```text\nretrieve → generate\n```\n\n예를 들어 검색 기반 QA 시스템은 다음처럼 구성할 수 있습니다.\n\n```python\nbuilder.add_node("retrieve", retrieve_node)\nbuilder.add_node("generate", generate_node)\n\nbuilder.add_edge(START, "retrieve") ...

# %% [markdown]
# ## Tool이 필요 없는 질문의 짧은 경로
#
# 같은 그래프라도 모델이 `tool_calls`를 만들지 않으면 Tool Node를 거치지 않는다. 일반적인 의견 질문을 넣어 `START → chatbot → END`의 짧은 경로와 앞의 반복 경로를 비교한다.
#
# 모델의 Tool 선택은 확률적일 수 있으므로 질문 문장만 보고 경로를 단정하지 않고, 마지막 `AIMessage.tool_calls`와 분기 로그를 확인한다.

# %%
user_input = 'AI가 인간의 삶을 어떻게 변화 시킬지 마크다운 형식으로 정리해줘'

initial_state = {'messages':HumanMessage(content=user_input)}

final_state = graph.invoke(initial_state)

trace_summary = summarize_messages(final_state['messages'])
print(trace_summary)
# Out:
# has_tool_calls = False
# [{'message_type': 'human', 'tool_calls': [], 'tool_call_id': None}, {'message_type': 'ai', 'tool_calls': [], 'tool_call_id': None}]

# %% [markdown]
# ## 최종 텍스트를 Markdown으로 렌더링하기
#
# `Markdown()`은 문자열을 받아 제목·목록 같은 Markdown 문법을 화면에 렌더링한다. 원본 `AIMessage.content`는 block 목록일 수 있으므로 문자열 인자가 필요한 곳에 그대로 전달하지 않는다.
#
# 앞에서 구분한 `AIMessage.text`를 사용하면 State와 원본 content 구조는 유지하면서 사용자에게 보여 줄 텍스트만 문자열로 꺼낼 수 있다.

# %%
from IPython.display import Markdown

answer_text = final_state['messages'][-1].text
Markdown(answer_text)
# Out:
# # AI가 인간의 삶을 변화시키는 방식
#
# ## 1. 일과 직업의 변화
#
# ### 긍정적 변화
# - 반복적이고 단순한 업무를 AI가 대신 수행
# - 문서 작성, 번역, 자료 분석, 고객 응대 등의 업무 자동화
# - 인간은 창의성, 판단력, 공감 능력이 필요한 일에 집중
# - 개인의 업무 생산성과 의사결정 속도 향상
# - 새로운 직업과 산업 등장
#   - AI 엔지니어
#   - 데이터 분석가
#   - 프롬프트 전문가
#   - AI 윤리·감사 전문가
#   - 인간-AI 협업 기획자
#
# ### 우려되는 변화
# - 일부 직업의 감소 또는 대체
# - 직업 간 소득 격차 확대
# - AI를 활용할 수 있는 사람과 그렇지 못한 사람 사이의 격차 발생
# - 평생교육과 직업 재훈련의 중요성 증가
#
# ---
#
# ## 2. 교육의 변화
#
# - 학생별 수준에 맞춘 개인 맞춤형 학습 가능
# - AI 튜터가 언제든 질문에 답하고 학습 방향을 제시
# - 외국어 회화, 작문, 수학 문제 풀이 등을 실시간으로 지원
# - 교사는 행정 업무보다 수업 설계와 학생 상담에 집중
# - 장애 학생이나 학습 소외 계층의 교육 접근성 향상
#
# ### 해결해야 할 문제
# - 학생의 사고력과 창의성이 약화될 가능성
# - 과제 대필 및 부정행위 증가
# - AI가 제공하는 잘못된 정보에 대한 검증 필요
# - 교육 격차가 오히려 확대될 가능성
#
# ---
#
# ## 3. 의료와 건강 관리
#
# - 질병의 조기 진단과 위험 예측
# - 의료 영상과 유전자 데이터 분석 지원
# - 환자별 맞춤형 치료법 개발
# - 웨어러블 기기를 통한 실시간 건강 관리
# - 고령자와 만성질환자의 생활 관리 지원
# - 신약 개발 기간과 비용 단축
#
# ### 기대되는 효과
# - 의료 서비스의 정확성과 효율성 향상
# - 의료진의 업무 부담 감소
# - 농어촌이나 의료 취약 지역의 원격 진료 지원
#
# ### 주의할 점
# - 의료 데이터 유출과 개인정보 침해
# - AI의 판단 오류에 대한 책임 문제
# - 경제적 여건에 따른 의료 서비스 격차
#
# ---
#
# ## 4. 일상생활의 변화
#
# - AI 비서가 일정, 쇼핑, 금융, 여행 등을 관리
# - 스마트홈을 통해 에너지 사용과 가전제품 자동 제어
# - 실시간 번역으로 언어 장벽 완화
# - 개인의 취향에 맞는 음악, 영상, 뉴스 추천
# - 로봇을 활용한 청소, 배달, 돌봄 서비스 확대
#
# AI는 앞으로 단순한 도구를 넘어 개인의 **디지털 동반자** 역할을 할 가능성이 큽니다.
#
# ---
#
# ## 5. 인간관계와 소통의 변화
#
# ### 긍정적 측면
# - 언어와 문화의 차이를 넘어선 소통 가능
# - 외로움을 느끼는 사람에게 대화와 정서적 지원 제공
# - 고령자, 장애인, 사회적 고립 상태에 있는 사람들의 소통 지원
#
# ### 부정적 측면
# - 인간보다 AI와 대화하는 시간이 늘어날 가능성
# - 실제 인간관계가 약화될 위험
# - AI가 만든 가짜 인물, 가짜 영상, 가짜 음성 확산
# - 개인의 감정과 행동이 AI에 의해 조작될 가능성
#
# ---
#
# ## 6. 경제와 산업의 변화
#
# - 생산성과 기업 경쟁력 향상
# - 제조업, 금융, 유통, 농업, 물류 등 다양한 산업 자동화
# - 소규모 기업도 고급 분석과 마케팅 서비스를 이용 가능
# - 새로운 시장과 비즈니스 모델 창출
# - 상품과 서비스의 개인화 확대
#
# 그러나 AI 기술을 보유한 기업과 그렇지 못한 기업 사이의 격차가 커질 수 있으며, 국가 간 기술 경쟁도 심화될 수 있습니다.
#
# ---
#
# ## 7. 문화와 창작의 변화
#
# - 글, 음악, 이미지, 영상 제작의 진입장벽 하락
# - 개인도 전문적인 수준의 콘텐츠를 쉽게 제작
# - 새로운 예술 형식과 협업 방식 등장
# - 창작자가 아이디어 구상과 편집에 AI 활용
#
# ### 논쟁이 예상되는 분야
# - AI가 만든 작품의 저작권
# - 원작자의 동의 없는 학습 데이터 사용
# - 인간 창작물과 AI 창작물의 가치 차이
# - 창작자의 일자리와 수익 구조 변화
#
# ---
#
# ## 8. 교통과 도시의 변화
#
# - 자율주행차와 지능형 교통 시스템 확대
# - 교통 체증과 사고 감소
# - 물류 및 배송 효율 향상
# - 도시의 에너지와 자원 사용 최적화
# - 재난 예측과 대응 능력 향상
#
# AI 기반 도시가 발전하면 생활은 편리해지지만, 도시 인프라가 해킹될 경우 큰 피해가 발생할 수 있습니다.
#
# ---
#
# ## 9. 환경과 기후 대응
#
# - 기후 변화 예측과 재난 조기 경보
# - 전력 생산과 소비 최적화
# - 농작물의 생산량과 병충해 예측
# - 물과 에너지 자원 관리
# - 탄소 배출 감축 기술 개발 지원
#
# 반면 대규모 AI 시스템을 운영하는 데 많은 전력과 물이 필요하므로, AI 자체의 환경 부담도 함께 관리해야 합니다.
#
# ---
#
# ## 10. 인간의 사고방식 변화
#
# AI가 정보를 빠르게 제공하면서 인간은 다음과 같은 능력을 더욱 중요하게 갖추어야 합니다.
#
# - 비판적 사고
# - 창의적 문제 해결 능력
# - 정보의 진위 확인 능력
# - 의사소통과 협업 능력
# - 공감과 윤리적 판단
# - AI를 올바르게 활용하는 능력
#
# 앞으로는 **무엇을 아는가**보다 **AI에게 무엇을 질문하고, 그 답을 어떻게 판단하며, 어떻게 활용하는가**가 중요해질 것입니다.
#
# ---
#
# ## 11. 가장 중요한 사회적 과제
#
# AI의 발전이 인간에게 이익이 되기 위해서는 다음 문제가 해결되어야 합니다.
#
# 1. **개인정보 보호**
# 2. **AI의 편향과 차별 방지**
# 3. **잘못된 정보와 가짜 콘텐츠 대응**
# 4. **AI 활용에 대한 책임 소재 확립**
# 5. **일자리 변화에 대한 사회적 안전망 마련**
# 6. **모든 사람이 AI 혜택을 누릴 수 있는 접근성 보장**
# 7. **AI 개발과 사용에 대한 윤리 기준 수립**
# 8. **인간의 자율성과 존엄성 보호**
#
# ---
#
# ## 결론
#
# AI는 인간의 삶을 더 편리하고 효율적으로 만들 뿐 아니라, 의료·교육·산업·문화·소통의 구조 자체를 변화시킬 것입니다. 하지만 AI가 인간을 완전히 대신하는 방향보다는, **인간의 능력을 확장하고 부족한 부분을 보완하는 협력 기술**로 활용하는 것이 바람직합니다.
#
# > AI의 미래는 기술 자체보다 그것을 어떤 가치와 규칙 아래에서 사용하는가에 달려 있습니다.

# %% [markdown]
# ## 직접 구현을 prebuilt 구성 요소로 교체하기
#
# 앞에서는 Tool 요청과 결과의 연결 원리를 보기 위해 Tool Node와 route function을 직접 구현했다. 실제 프로젝트에서는 LangGraph가 제공하는 prebuilt 구성 요소로 같은 역할을 짧게 구성할 수 있다.
#
# ### 직접 구현
#
# - `name·args·id → Tool 실행 → ToolMessage` 변환을 코드로 확인하기 좋다.
# - 입력 검증과 예외 처리 범위를 직접 정해야 한다.
#
# ### prebuilt 구현
#
# - `PrebuiltToolNode`: 마지막 `AIMessage.tool_calls`를 실행하고 같은 ID의 `ToolMessage`를 반환한다. 병렬 Tool 호출과 오류 처리도 지원한다.
# - `prebuilt_tools_condition`: 마지막 message에 요청이 있으면 `"tools"`, 없으면 `"__end__"`를 반환한다.
#
# 두 반환값이 이미 등록한 `tools` Node와 LangGraph 종료 지점의 이름이므로 이 셀에서는 별도 `path_map`을 생략한다.

# %%
from langgraph.graph import START, StateGraph
from langgraph.prebuilt import ToolNode as PrebuiltToolNode
from langgraph.prebuilt import tools_condition as prebuilt_tools_condition

prebuild_tool_node = PrebuiltToolNode(tools)

prebuild_workflow = StateGraph(State)
prebuild_workflow.add_node('chatbot', chatbot)
prebuild_workflow.add_node('tools', prebuild_tool_node) # Tool node 등록

prebuild_workflow.add_edge(START, 'chatbot')
prebuild_workflow.add_edge('tools', 'chatbot')

(prebuild_workflow.add_conditional_edges(
    'chatbot', prebuilt_tools_condition, # Tool 요청 유무로 다음 node 판별하는 함수
))

prebuilt_graph = prebuild_workflow.compile()

prebuilt_graph

# %%
user_input = 'LangGraph Prebuilt에 대해서 검색 Tool 사용해서 알려줘'
initial_state = {
    'messages':[HumanMessage(content=user_input)]
}

final_state = prebuilt_graph.invoke(initial_state)

trace_summary = summarize_messages(final_state['messages'])
print(trace_summary)

Markdown(final_state['messages'][-1].text)
# Out:
# [{'message_type': 'human', 'tool_calls': [], 'tool_call_id': None}, {'message_type': 'ai', 'tool_calls': [{'name': 'tavily_search', 'id': 'call_zEPbA72R4IWbrTN1b4sI22FM'}], 'tool_call_id': None}, {'message_type': 'tool', 'tool_calls': [], 'tool_call_id': 'call_zEPbA72R4IWbrTN1b4sI22FM'}, {'message_type': 'ai', 'tool_calls': [{'name': 'tavily_search', 'id': 'call_x5pqAyormMWTRltoHDiGXjRC'}], 'tool_call_id': None}, {'message_type': 'tool', 'tool_calls': [], 'tool_call_id': 'call_x5pqAyormMWTRltoHDiGXjRC'}, {'message_type': 'ai', 'tool_calls': [], 'tool_call_id': None}]
# ## LangGraph Prebuilt이란?
#
# **LangGraph Prebuilt**는 LangGraph에서 자주 사용하는 에이전트 구성 요소를 미리 구현해 둔 패키지입니다.
# 직접 `StateGraph`를 만들고 노드·조건·Tool 실행 로직을 작성하지 않아도, 기본적인 ReAct 에이전트나 Tool 실행 구조를 빠르게 만들 수 있습니다.
#
# 쉽게 말하면:
#
# > LangGraph로 에이전트를 만들 때 반복적으로 작성하는 보일러플레이트를 미리 만들어 둔 것
#
# 입니다.
#
# ---
#
# ## 주요 구성 요소
#
# 대표적으로 다음과 같은 기능이 있습니다.
#
# ### 1. ReAct Agent
#
# LLM이 다음과 같은 과정을 반복하도록 구성된 에이전트입니다.
#
# 1. 사용자 질문 분석
# 2. 필요한 Tool 선택
# 3. Tool 실행
# 4. 실행 결과 확인
# 5. 최종 답변 생성
#
# 예를 들어 계산기, 웹 검색, 데이터베이스 조회 Tool을 연결하면 LLM이 상황에 따라 Tool을 호출합니다.
#
# 기존에는 다음과 같이 사용했습니다.
#
# ```python
# from langgraph.prebuilt import create_react_agent
# ```
#
# 다만 최신 LangChain/LangGraph 생태계에서는 `create_react_agent` 대신 다음 API 사용이 권장되는 방향으로 변경되고 있습니다.
#
# ```python
# from langchain.agents import create_agent
# ```
#
# ---
#
# ### 2. `ToolNode`
#
# LLM의 Tool 호출 요청을 실제 Tool 실행으로 변환하는 노드입니다.
#
# ```python
# from langgraph.prebuilt import ToolNode
# ```
#
# 예를 들어 LLM이 다음과 같은 Tool Call을 생성했다고 가정합니다.
#
# ```json
# {
#   "name": "search",
#   "args": {
#     "query": "LangGraph란?"
#   }
# }
# ```
#
# `ToolNode`가 해당 Tool을 찾아 실행하고 결과를 LangGraph 상태에 반영합니다.
#
# 직접 구현한다면 다음과 같은 작업이 필요합니다.
#
# - Tool Call 파싱
# - Tool 이름 확인
# - 인자 전달
# - Tool 실행
# - 오류 처리
# - ToolMessage 생성
#
# `ToolNode`는 이러한 과정을 대신 처리합니다.
#
# ---
#
# ### 3. `tools_condition`
#
# LLM 결과에 Tool Call이 있는지 확인해서 다음 노드를 결정하는 조건 함수입니다.
#
# ```python
# from langgraph.prebuilt import tools_condition
# ```
#
# 일반적인 흐름은 다음과 같습니다.
#
# ```text
# LLM 호출
#  ├─ Tool Call 있음 → ToolNode
#  └─ Tool Call 없음 → 종료
# ```
#
# 직접 조건문을 작성하지 않고도 Tool 사용 여부에 따라 그래프를 분기할 수 있습니다.
#
# ---
#
# ### 4. 상태 및 Store 주입 기능
#
# Prebuilt에는 Tool이 LangGraph의 상태나 영속적인 Store에 접근할 수 있도록 해 주는 기능도 포함됩니다.
#
# 대표적인 예시는 다음과 같습니다.
#
# - 현재 그래프 상태를 Tool에 주입
# - 사용자 ID나 세션 정보 전달
# - 장기 메모리 Store 접근
# - Tool 실행 시 필요한 런타임 정보 전달
#
# 이 기능을 사용하면 Tool이 단순히 입력값만 받는 것이 아니라, 현재 대화 상태나 사용자별 정보를 활용할 수 있습니다.
#
# ---
#
# ## 가장 간단한 사용 예시
#
# ### 최신 스타일: `create_agent`
#
# ```python
# from langchain.agents import create_agent
# from langchain_core.tools import tool
# from langchain_openai import ChatOpenAI
#
#
# @tool
# def calculator(expression: str) -> str:
#     """간단한 수식을 계산합니다."""
#     try:
#         return str(eval(expression, {"__builtins__": {}}, {}))
#     except Exception as e:
#         return f"계산 오류: {e}"
#
#
# model = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
# )
#
# agent = create_agent(
#     model=model,
#     tools=[calculator],
#     system_prompt="필요하면 계산기 Tool을 사용하세요.",
# )
#
# result = agent.invoke({
#     "messages": [
#         {
#             "role": "user",
#             "content": "123 * 456을 계산해 줘."
#         }
#     ]
# })
#
# print(result["messages"][-1].content)
# ```
#
# 이 방식에서는 내부적으로 Tool 호출과 반복 실행 흐름이 구성됩니다.
#
# ---
#
# ## 기존 LangGraph Prebuilt 방식
#
# 기존 코드나 일부 문서에서는 다음과 같은 형태를 많이 볼 수 있습니다.
#
# ```python
# from langgraph.prebuilt import create_react_agent
# from langchain_core.tools import tool
# from langchain_openai import ChatOpenAI
#
#
# @tool
# def get_weather(city: str) -> str:
#     """도시의 날씨를 조회합니다."""
#     return f"{city}의 날씨는 맑습니다."
#
#
# model = ChatOpenAI(
#     model="gpt-4o-mini",
#     temperature=0,
# )
#
# agent = create_react_agent(
#     model=model,
#     tools=[get_weather],
# )
#
# result = agent.invoke({
#     "messages": [
#         {
#             "role": "user",
#             "content": "서울 날씨 알려줘."
#         }
#     ]
# })
#
# print(result["messages"][-1].content)
# ```
#
# 단, 프로젝트의 LangGraph/LangChain 버전에 따라 import 경로와 인자 이름이 다를 수 있습니다. 신규 프로젝트라면 공식 최신 문서 기준으로 `langchain.agents.create_agent` 사용 여부를 확인하는 것이 좋습니다.
#
# ---
#
# ## 직접 그래프를 만드는 방식과 비교
#
# ### Prebuilt 사용
#
# ```text
# 사용자 입력
#    ↓
# Prebuilt Agent
#    ↓
# LLM이 Tool 선택
#    ↓
# Tool 실행
#    ↓
# 최종 응답
# ```
#
# 장점:
#
# - 빠르게 프로토타입 작성 가능
# - Tool 호출 로직을 직접 작성하지 않아도 됨
# - 기본적인 ReAct 패턴 구현이 쉬움
# - 예제와 유지보수가 상대적으로 간단함
#
# 단점:
#
# - 복잡한 업무 흐름 제어에 한계가 있음
# - 특정 단계에 대한 세밀한 제어가 어려울 수 있음
# - 사용자 정의 상태 구조를 깊게 활용하려면 직접 Graph를 만드는 편이 나음
# - 실행 정책이나 승인 프로세스가 복잡하면 Prebuilt만으로 부족할 수 있음
#
# ---
#
# ### Custom StateGraph 사용
#
# 직접 그래프를 만들면 다음과 같은 흐름을 세밀하게 설계할 수 있습니다.
#
# ```text
# 질문 분류
#  ├─ 일반 질문 → 답변 Agent
#  ├─ 검색 질문 → 검색 Agent
#  ├─ 결제 요청 → 사용자 승인
#  └─ 민감한 요청 → 관리자 검토
# ```
#
# 또한 다음을 직접 정의할 수 있습니다.
#
# - 상태 스키마
# - 노드별 실행 순서
# - 조건부 라우팅
# - 재시도 정책
# - 사람 승인 단계
# - 중단 및 재개
# - 병렬 실행
# - 장기 메모리 처리
#
# 즉, Prebuilt는 **일반적인 에이전트**, Custom Graph는 **업무 프로세스형 에이전트**에 적합합니다.
#
# ---
#
# ## 언제 Prebuilt를 사용하면 좋은가?
#
# 다음과 같은 경우에 적합합니다.
#
# - LLM에 몇 개의 Tool을 연결하고 싶을 때
# - 간단한 ReAct Agent를 빠르게 만들고 싶을 때
# - LangGraph를 처음 학습할 때
# - 프로토타입이나 PoC를 만들 때
# - Tool 호출과 대화 흐름이 비교적 단순할 때
#
# 반대로 다음과 같은 경우에는 Custom Graph를 고려하는 것이 좋습니다.
#
# - 여러 Agent 간 명확한 라우팅이 필요할 때
# - 특정 Tool 실행 전에 사람 승인이 필요할 때
# - 업무 단계가 정해져 있을 때
# - 상태와 메모리를 복잡하게 관리해야 할 때
# - 실패 시 재시도·보상 처리·중단/재개가 필요할 때
#
# ---
#
# ## 설치
#
# 일반적으로 다음 패키지를 설치합니다.
#
# ```bash
# pip install -U langgraph langchain
# ```
#
# 모델에 따라 추가 패키지가 필요합니다.
#
# ```bash
# pip install -U langchain-openai
# ```
#
# Anthropic 모델을 사용한다면:
#
# ```bash
# pip install -U langchain-anthropic
# ```
#
# 기존 버전에서 별도의 Prebuilt 패키지를 직접 설치해야 하는 경우도 있으므로, 현재 프로젝트의 버전과 공식 문서를 함께 확인하는 것이 좋습니다.
#
# ---
#
# ## 핵심 정리
#
# | 항목 | 설명 |
# |---|---|
# | LangGraph | 상태 기반 Agent Workflow 프레임워크 |
# | LangGraph Prebuilt | 자주 사용하는 Agent/Node/조건을 미리 구현한 기능 |
# | ReAct Agent | LLM이 Tool을 선택하고 실행하는 기본 에이전트 |
# | `ToolNode` | Tool Call을 실제 Tool 실행으로 처리 |
# | `tools_condition` | Tool 호출 여부에 따라 그래프 분기 |
# | `create_agent` | 최신 LangChain 계열에서 권장되는 에이전트 생성 방식 |
# | Custom Graph | 복잡한 업무 흐름을 직접 설계할 때 사용 |
#
# 정리하면, **LangGraph Prebuilt는 LangGraph의 모든 기능을 대체하는 것이 아니라, 자주 쓰는 Agent 패턴을 빠르게 사용할 수 있게 해 주는 출발점**입니다. 단순한 Tool Agent는 Prebuilt로 시작하고, 승인·라우팅·메모리·재시도 등 복잡한 흐름이 필요해지면 Custom StateGraph로 확장하는 방식이 일반적입니다.
#
# 참고할 공식 자료:
#
# - [LangGraph 공식 문서](https://docs.langchain.com/oss/python/langgraph/)
# - [LangGraph Agents 문서](https://docs.langchain.com/oss/python/langgraph/agents)
# - [LangGraph GitHub 저장소](https://github.com/langchain-ai/langgraph)
# - [LangGraph Prebuilt 소스](https://github.com/langchain-ai/langgraph/tree/main/libs/prebuilt)
#
# 참고로 검색 Tool로 공식 문서를 조회하려 했지만 현재 검색 서비스 인증 오류가 발생하여, 위 공식 링크와 일반적으로 알려진 최신 API 구조를 기준으로 설명했습니다.
